# %%
import pandas as pd
import os

# %%
cbs
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 1
#
# ----> 1 cbs
#
#
#
# NameError: name 'cbs' is not defined

# %%
cbs_df.head
# Out:
# <bound method NDFrame.head of        URL,PDF,Title,Subtitle,Date,Authorname,Role,Gender,CentralBank,Country,text,text_original,Filename,Language,Source  \
# 0       https://www.cbaruba.org/readBlob.do?id=10756,,...
# 1       https://www.cbaruba.org/readBlob.do?id=7515,,S...
# 2       https://www.cbaruba.org/readBlob.do?id=7518,,S...
# 3       https://www.cbaruba.org/readBlob.do?id=7548,,I...
# 4       https://www.cbaruba.org/readBlob.do?id=7554,,S...
# ...                                                   ...
# 186019        that we are up to the challenge. Thank you.
# 186020                                           CONTACTS
# 186021                                          Jean Tate
# 186022                                       404-498-8035
# 186023  ,,beyond-short-term-interests-521702,English,A...
#
#                                                Unnamed: 1  \
# 0           to restore and regenerate our natural capital
# ...
